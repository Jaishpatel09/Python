# %%
tpl=(5,7,6,39,4,55)
tpl+=("Hello",4,55,13)
print(tpl)
# Out:
# (5, 7, 6, 39, 4, 55, 'Hello', 4, 55, 13)

# %%
tpl=(5,7,6,39,4,55)
print(id(tpl))
tpl+=("hello",5,7,9)
print(id(tpl))
print(tpl)
# Out:
# 2146694174304
# 2146694798016
# (5, 7, 6, 39, 4, 55, 'hello', 5, 7, 9)

# %%
tpl=(5,7,6,39,4,55)
del tpl

# %%
tpl=(5,7,6,39,4,55)
print(sorted(tpl))
print(tpl)
# Out:
# [4, 5, 6, 7, 39, 55]
# (5, 7, 6, 39, 4, 55)

# %%
tpl=(5,7,6,39,4,55)
print(sorted(tpl,reverse=True))
print(tpl)
# Out:
# [55, 39, 7, 6, 5, 4]
# (5, 7, 6, 39, 4, 55)

# %%
tpl=(5,7,6,39,4,55)
tpl=list(tpl)
tpl[4]=50
tpl=tuple(tpl)
print(tpl)
# Out:
# (5, 7, 6, 39, 50, 55)

# %%
#String 
a='Kaise hai aap log'
print(a)
# Out:
# Kaise hai aap log

# %%
a="Hello Everyone Let's Learn String In Python"
# a[::-10]
# a[-10::-5]
# a[-10:-1:5]
# a[::-1]
print(a[-2:-11:-5])
# Out:
# o
