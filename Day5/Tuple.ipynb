# %%
tpl=(5,7,6,39,4,55)
tpl+=("Hello",4,55,13)
print(tpl)
# Out:
# (5, 7, 6, 39, 4, 55, 'Hello', 4, 55, 13)

# %%
tpl=(5,7,6,39,4,55)
print(id(tpl))
tpl+=("hello",5,7,9)
print(id(tpl))
print(tpl)
# Out:
# 2146694174304
# 2146694798016
# (5, 7, 6, 39, 4, 55, 'hello', 5, 7, 9)

# %%
tpl=(5,7,6,39,4,55)
del tpl
