# %%
list1 = ['"red',"orange","green","blue","white"]
list2 = ["black", "yellow", "green" "pink"]
list1=[]
list2=[]
for i in color1:
    if i not in colour2:
        list1.append(i)

for i in colour2:
    if i not in color1:
        list2.append(i)
print (list1)
print (list2)
