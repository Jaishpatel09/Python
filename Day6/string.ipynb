# %%
word_lst=['hello' 'user i am','learning python']
temp=" # ".join(word_lst)
print(temp)
# Out:
# hellouser i am # learning python

# %%
x="jaish patel"
print(x.upper())

print(x.capitalize())
# Out:
# JAISH PATEL
# Jaish patel

# %%
sentence="This is a good day to learn python."
index=sentence.find("s")
print(index)
# Out:
# 3

# %%
text = "apple banana cherry apple"
modified_text=text.replace("apple","orange")
print(modified_text)
# Out:
# orange banana cherry orange

# %%
text='global college #1 '
text1=sorted(text)
print(text1)
a=' '.join(text1)
print(text)
print(a)
# Out:
# [' ', ' ', ' ', '#', '1', 'a', 'b', 'c', 'e', 'e', 'g', 'g', 'l', 'l', 'l', 'l', 'o', 'o']
# global college #1
#       # 1 a b c e e g g l l l l o o
